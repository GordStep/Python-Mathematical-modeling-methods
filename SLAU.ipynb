# %% [markdown]
# Вариант № 21
# Решить методами Гаусса и Якоби, найти λmin, λmax, определить число обусловленности матрицы μ = ‖A‖·‖A−1‖.
# Сделать вывод нормы вектора невязки для обоих методов.
#
# $$
# \begin{cases}
#     b_1 x_1 + c_1 x_2 = f_1 \\
#     a_2 x_1 + b_2 x_2 + c_2 x_3 = f_2 \\
#     a_3 x_2 + b_3 x_3 + c_3 x_4 = f_3 \\
#     ... \\
#     a_n x_{n-1} + b_n x_n + c_n x_{n + 1} = f_n \\
#     p_1 x_1 + p_2 x_2 + \cdots + p_{n - 1} x_{n - 1} + p_n x_n + p_{n + 1} x_{n + 1} = f_{n + 1}
# \end{cases}     $$
#
# $$
# n = 19, \ b_1 = 1, \ c_1 = 0, \ f_1 = 1, \\
# a_i = c_i = 1, \ b_i = -2, \ p_i = 2, \ p_i = 2 / i^2, \ i = 2, 3,...,n, \\
# f_{n + 1} = -n / 3, \ p_1 = p_{n + 1} = 1
# $$
#
# $$
# \begin{pmatrix}
#     1 & 0 & 0 & 0 & 0 \\
#     1 & -2 & 1 & 0 & 0 \\
#     0 & 1 & -2 & 1 & 0 \\
#     \cdots \\
#     0 &  \cdots & 0 & 1 & -2 & 1 \\
#     1 &
# \end{pmatrix}
# $$
